# %%
import pandas as pd

# %%
data1= pd.read_csv('results_original_predict_transportation_choice.csv')
data1.head()
# Out:
#   Unnamed: 0  P(mode1)  P(mode2)  P(mode3)   P(mode4)  P(mode5)  origin  \
# 0        3-4  0.000000  0.739250  0.565102   3.753164  0.942485       3
# 1        3-7  2.514212  5.736936  3.988082  19.192310  4.568461       3
# 2        3-9  0.000000  0.645932  0.321317   0.904404  0.128346       3
# 3       3-10  0.000000  0.896300  0.111315   1.759122  0.233263       3
# 4       3-11  0.000000  0.082089  0.000000   3.427344  0.490567       3
#
#    destination
# 0            4
# 1            7
# 2            9
# 3           10
# 4           11

# %%
data2= pd.read_csv('results_add2.75_predict_transportation_choice.csv')
data2.head()
# Out:
#   ODpair  P(mode1)  P(mode2)  P(mode3)   P(mode4)  P(mode5)  origin  \
# 0    3-4  0.000000  0.644911  0.595489   3.811452  0.948148       3
# 1    3-7  2.514212  5.736936  3.988082  19.192310  4.568461       3
# 2    3-9  0.000000  0.645932  0.321317   0.904404  0.128346       3
# 3   3-10  0.000000  0.896300  0.111315   1.759122  0.233263       3
# 4   3-11  0.000000  0.082089  0.000000   3.427344  0.490567       3
#
#    destination
# 0            4
# 1            7
# 2            9
# 3           10
# 4           11

# %%
data3= pd.read_csv('results_add10_predict_transportation_choice.csv')
data3.head()
# Out:
#   Unnamed: 0  P(mode1)  P(mode2)  P(mode3)   P(mode4)  P(mode5)  origin  \
# 0        3-7  2.514212  5.736936  3.988082  19.192310  4.568461       3
# 1        3-9  0.000000  0.645932  0.321317   0.904404  0.128346       3
# 2       3-10  0.000000  0.896300  0.111315   1.759122  0.233263       3
# 3       3-11  0.000000  0.082089  0.000000   3.427344  0.490567       3
# 4       3-14  0.000000  1.089302  0.258752   7.821043  1.830903       3
#
#    destination
# 0            7
# 1            9
# 2           10
# 3           11
# 4           14

# %%
data1_sum = data1.groupby(data1.origin).sum()
data1_sum.head()
# Out:
#             P(mode1)     P(mode2)     P(mode3)      P(mode4)     P(mode5)  \
# origin
# 3         919.220815  1032.030446   856.827889   4532.134189  1365.786661
# 4        2478.643144  1244.857983  1137.066639   3614.908023  2141.524211
# 5          49.629786  1716.445501  1186.672071   4558.662219   716.590423
# 6         310.881579  1042.891135   902.121017   2651.376865   361.729405
# 7       10889.777667  4194.086863  3496.564102  15648.805360  2458.766008
#
#         destination
# origin
# 3             32429
# 4             31628
# 5             32325
# 6             31051
# 7             33488

# %%
data2_sum = data2.groupby(data1.origin).sum()
data2_sum.head()
# Out:
#             P(mode1)     P(mode2)     P(mode3)      P(mode4)     P(mode5)  \
# origin
# 3         894.892536  1011.111907   862.569513   4567.562664  1369.863381
# 4        2280.708578  1115.327626  1237.956619   3767.563601  2215.443576
# 5          49.034250  1696.632499  1187.013977   4577.991710   717.327564
# 6         308.101604  1014.043797   908.125166   2675.730478   362.998956
# 7       10324.022551  3997.375706  3668.331328  16187.876191  2510.394224
#
#         origin  destination
# origin
# 3          711        32429
# 4          936        31628
# 5         1185        32325
# 6         1368        31051
# 7         1729        33488

# %%
data3_sum = data3.groupby(data1.origin).sum()
data3_sum.head()
# Out:
#            P(mode1)     P(mode2)     P(mode3)     P(mode4)     P(mode5)  \
# origin
# 3        718.096187  1296.775042  1044.180519  3116.024730  1169.923522
# 4         76.124770  1501.541779  1069.538478  2600.309053   442.485919
# 5       2416.013859  2028.462515  1616.741592  3702.697603   676.084432
# 6       2226.629767  1583.642477  1319.100954  2849.279881   766.346920
# 7        996.808096  1561.244970  1283.296854  2873.462350  1108.187730
#
#         origin  destination
# origin
# 3          785        27926
# 4         1242        29363
# 5         1540        30969
# 6         1819        31028
# 7         2357        33641

# %%
difference_between_0_and_2_75 =data2_sum - data1_sum
difference_between_0_and_2_75 = difference_between_0_and_2_75.drop(['destination', 'origin'], axis=1)
difference_between_0_and_2_75['origin'] = difference_between_0_and_2_75.index
difference_between_0_and_2_75.head()
# Out:
#           P(mode1)    P(mode2)    P(mode3)    P(mode4)   P(mode5)  origin
# origin
# 3       -24.328279  -20.918539    5.741624   35.428475   4.076720       3
# 4      -197.934565 -129.530357  100.889980  152.655578  73.919365       4
# 5        -0.595536  -19.813002    0.341905   19.329491   0.737141       5
# 6        -2.779975  -28.847338    6.004149   24.353614   1.269551       6
# 7      -565.755116 -196.711157  171.767226  539.070831  51.628216       7

# %%
differences = pd.DataFrame()
differences['P(mode1)'] = [difference_between_0_and_2_75.abs().sort_values(by ='P(mode1)', ascending=False).iloc[0].origin.astype('int')]
differences['P(mode2)'] = [difference_between_0_and_2_75.abs().sort_values(by ='P(mode2)', ascending=False).iloc[0].origin.astype('int')]
differences['P(mode3)'] = [difference_between_0_and_2_75.abs().sort_values(by ='P(mode3)', ascending=False).iloc[0].origin.astype('int')]
differences['P(mode4)'] = [difference_between_0_and_2_75.abs().sort_values(by ='P(mode4)', ascending=False).iloc[0].origin.astype('int')]
differences['P(mode5)'] = [difference_between_0_and_2_75.abs().sort_values(by ='P(mode5)', ascending=False).iloc[0].origin.astype('int')]
differences
# Out:
#    P(mode1)  P(mode2)  P(mode3)  P(mode4)  P(mode5)
# 0         7        79        79         7       232

# %%
difference_between_0_and_10 =data3_sum - data1_sum
difference_between_0_and_10 = difference_between_0_and_10.drop(['destination', 'origin'], axis=1)
difference_between_0_and_10['origin'] = difference_between_0_and_10.index
difference_between_0_and_10.head()
# Out:
#            P(mode1)     P(mode2)     P(mode3)      P(mode4)     P(mode5)  \
# origin
# 3       -201.124628   264.744597   187.352629  -1416.109459  -195.863139
# 4      -2402.518373   256.683796   -67.528161  -1014.598970 -1699.038292
# 5       2366.384073   312.017014   430.069520   -855.964616   -40.505991
# 6       1915.748188   540.751342   416.979938    197.903017   404.617516
# 7      -9892.969571 -2632.841893 -2213.267248 -12775.343010 -1350.578278
#
#         origin
# origin
# 3            3
# 4            4
# 5            5
# 6            6
# 7            7

# %%
differences2 = pd.DataFrame()
differences2['P(mode1)'] = [difference_between_0_and_10.abs().sort_values(by ='P(mode1)', ascending=False).iloc[0].origin.astype('int')]
differences2['P(mode2)'] = [difference_between_0_and_10.abs().sort_values(by ='P(mode2)', ascending=False).iloc[0].origin.astype('int')]
differences2['P(mode3)'] = [difference_between_0_and_10.abs().sort_values(by ='P(mode3)', ascending=False).iloc[0].origin.astype('int')]
differences2['P(mode4)'] = [difference_between_0_and_10.abs().sort_values(by ='P(mode4)', ascending=False).iloc[0].origin.astype('int')]
differences2['P(mode5)'] = [difference_between_0_and_10.abs().sort_values(by ='P(mode5)', ascending=False).iloc[0].origin.astype('int')]
differences2
# Out:
#    P(mode1)  P(mode2)  P(mode3)  P(mode4)  P(mode5)
# 0         7        39       228       203       203

# %%
differences_ = pd.concat([differences, differences2], axis=0)
differences_.iloc[0,0] = "7 (Astoria)"
differences_.iloc[1,0] = "7 (Astoria)"
differences_.iloc[0,3] = "7 (Astoria)"

differences_.iloc[0,1] = "79 (East Village)"
differences_.iloc[0,2] = "79 (East Village)"
differences_.iloc[0,4] = "232 (University Heights/Morris Heights)"

differences_.iloc[1,1] = "39 (Canarsie)"
differences_.iloc[1,2] = "228 (Sunset Park West)"
differences_.iloc[1,3] = "203 (Rosedale)"
differences_.iloc[1,4] = "203 (Rosedale)"


differences_['taxi zone with the biggest mode change'] = ['orginal to $2.75','orginal to $10']
differences_=differences_.set_index(['taxi zone with the biggest mode change'])
differences_
# Out:
#                                            P(mode1)           P(mode2)  \
# taxi zone with the biggest mode change
# orginal to $2.75                        7 (Astoria)  79 (East Village)
# orginal to $10                          7 (Astoria)      39 (Canarsie)
#
#                                                       P(mode3)  \
# taxi zone with the biggest mode change
# orginal to $2.75                             79 (East Village)
# orginal to $10                          228 (Sunset Park West)
#
#                                               P(mode4)  \
# taxi zone with the biggest mode change
# orginal to $2.75                           7 (Astoria)
# orginal to $10                          203 (Rosedale)
#
#                                                                        P(mode5)
# taxi zone with the biggest mode change
# orginal to $2.75                        232 (University Heights/Morris Heights)
# orginal to $10                                                   203 (Rosedale)

# %%
difference_between_0_and_2_75[difference_between_0_and_2_75.origin ==7]
# Out:
#           P(mode1)    P(mode2)    P(mode3)    P(mode4)   P(mode5)  origin
# origin
# 7      -565.755116 -196.711157  171.767226  539.070831  51.628216       7

# %%
data1_sum[data1_sum.index==44]
# Out:
#          P(mode1)     P(mode2)    P(mode3)     P(mode4)     P(mode5)  \
# origin
# 44      75.515423  1078.602062  811.557512  3525.030021  1702.294982
#
#         destination
# origin
# 44            32705

# %%
data2_sum[data2_sum.index==44]
# Out:
#          P(mode1)     P(mode2)    P(mode3)     P(mode4)     P(mode5)  origin  \
# origin
# 44      75.515423  1064.438279  812.910754  3536.797701  1703.337843   10560
#
#         destination
# origin
# 44            32705

# %%
diff = difference_between_0_and_2_75.sort_values(by ='P(mode3)', ascending=False)
diff10 = difference_between_0_and_10.sort_values(by ='P(mode3)', ascending=False)
diff.head()
# Out:
#           P(mode1)    P(mode2)    P(mode3)    P(mode4)   P(mode5)  origin
# origin
# 79     -373.068429 -336.930503  275.673965  386.266671  48.058296      79
# 48     -300.850878 -282.099731  231.063098  311.406673  40.480838      48
# 263    -336.506407 -305.774445  203.182851  349.627921  89.470080     263
# 141    -272.848280 -276.882919  186.961697  266.478832  96.290670     141
# 107    -244.082518 -202.650896  178.090775  244.507561  24.135077     107

# %%
import geopandas as gpd
taxi_zone = gpd.GeoDataFrame.from_file('NYC_Taxi_Zones/geo_export_0448e136-78e4-47d2-a4a1-e87279ee0d1b.shp')
taxi_zone_shp = taxi_zone[['objectid', 'zone', 'geometry']].set_index('objectid')
taxi_zone_shp.index = taxi_zone_shp.index.astype(int)
taxi_zone_shp.head()
taxi_zone_shp.head()
#zonone_geo = tlc_shps[['LocationID', 'geometry','Shape_Area']]
# Out:
#                              zone  \
# objectid
# 1                  Newark Airport
# 2                     Jamaica Bay
# 3         Allerton/Pelham Gardens
# 4                   Alphabet City
# 5                   Arden Heights
#
#                                                    geometry
# objectid
# 1         POLYGON ((-74.18445299999996 40.6949959999999,...
# 2         (POLYGON ((-73.82337597260663 40.6389870471767...
# 3         POLYGON ((-73.84792614099985 40.87134223399991...
# 4         POLYGON ((-73.97177410965318 40.72582128133706...
# 5         POLYGON ((-74.17421738099989 40.5625680859999,...

# %%
diff_taxi = gpd.GeoDataFrame(pd.merge(diff, taxi_zone_shp, left_index=True, right_index=True))
diff_taxi.head()
# Out:
#        P(mode1)    P(mode2)    P(mode3)    P(mode4)   P(mode5)  origin  \
# 79  -373.068429 -336.930503  275.673965  386.266671  48.058296      79
# 48  -300.850878 -282.099731  231.063098  311.406673  40.480838      48
# 263 -336.506407 -305.774445  203.182851  349.627921  89.470080     263
# 141 -272.848280 -276.882919  186.961697  266.478832  96.290670     141
# 107 -244.082518 -202.650896  178.090775  244.507561  24.135077     107
#
#                 zone                                           geometry
# 79      East Village  POLYGON ((-73.98377990999991 40.72153595399992...
# 48      Clinton East  POLYGON ((-73.99117738199989 40.75532984899993...
# 263   Yorkville West  POLYGON ((-73.95218621999996 40.77301984499992...
# 141  Lenox Hill West  POLYGON ((-73.96177668399997 40.75987971599994...
# 107         Gramercy  POLYGON ((-73.98238628799993 40.73141124499994...

# %%
diff_taxi_10 = gpd.GeoDataFrame(pd.merge(diff10, taxi_zone_shp, left_index=True, right_index=True))
diff_taxi_10.head()
# Out:
#         P(mode1)     P(mode2)     P(mode3)      P(mode4)     P(mode5)  origin  \
# 228  1271.125233  1832.198822  5675.172266  11515.645656  4743.858024     228
# 203  5140.199577  1414.185291  4320.784544  32751.678274  7416.152314     203
# 258  3085.924027   883.065661  4153.393766  24645.367241  5628.249305     258
# 214  3911.003362  1172.471435  4135.147019  17568.103016  2409.275168     214
# 199  3724.300799  2770.166553  3971.661087  21655.192775  3951.678787     199
#
#                          zone  \
# 228          Sunset Park West
# 203                  Rosedale
# 258                 Woodhaven
# 214  South Beach/Dongan Hills
# 199             Rikers Island
#
#                                               geometry
# 228  POLYGON ((-73.9969179149999 40.66915348399991,...
# 203  POLYGON ((-73.72753500301229 40.67393028414612...
# 258  POLYGON ((-73.84504194899991 40.68931894699996...
# 214  POLYGON ((-74.08491019899996 40.59570472799985...
# 199  POLYGON ((-73.88885148496313 40.79870632895877...

# %%
type(diff_taxi)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,3,figsize=(50,30))
# fig = plt.figure(figsize=(22,100))
# ax1 = fig.add_subplot(1,3,1)
diff_taxi.plot(column='P(mode1)', cmap='bone', edgecolor='black', legend=True, scheme='equal_interval'
                 ,ax=ax[0],legend_kwds={'loc':2,'fontsize':12})
# ax1.set_legend({'size':5})
# leg1 = ax1.get_legend()
# leg1.set_bbox_to_anchor((0.35,0.95,0,0))
ax[0].set_title('Changed population amount in choosing taxi under +$2.75 surcharge')
# plt.legend(prop={'size':6})

# ax2 = fig.add_subplot(1,3,2)
diff_taxi.plot(column='P(mode2)', cmap='bone', edgecolor='black', legend=True, scheme='equal_interval',
                  ax=ax[1],legend_kwds={'loc':2})
ax[1].set_title('Changed population amount in choosing FHV under +$2.5 surcharge')

# ax3 = fig.add_subplot(1,3,3)
diff_taxi.plot(column='P(mode3)', cmap='bone', edgecolor='black', legend=True,scheme='equal_interval',
                   ax=ax[2],legend_kwds={'loc':2})
ax[2].set_title('Changed population amount in choosing taxi under +$0.75 surcharge')

#plt.savefig('changed_population_2_75.png')

plt.show()

# %%
plt.savefig('')
